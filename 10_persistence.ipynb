# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.7)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'The joke relies on a play on words, which is a common technique used in puns. A pun is a form of wordplay that exploits multiple meanings of a word or phrase, often with a humorous effect.\n\nIn this case, the word "crusty" has a double meaning:\n\n1. A crust is a hard, outer layer on a pizza, typically made of bread.\n2. To be "crusty" can also mean to be in a bad mood or irritable.\n\nThe joke sets up the expectation that the pizza might be in a bad mood because of some external reason, but instead, it uses the word "crusty" to refer to the pizza\'s physical composition, creating a clever and unexpected connection between the setup and the punchline.\n\nThe humor comes from the unexpected twist on the word\'s meaning, which creates a surprise and a clever connection between the setup and the punchline.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke relies on a play on words, which is a common technique used in puns. A pun is a form of wordplay that exploits multiple meanings of a word or phrase, often with a humorous effect.\n\nIn this case, the word "crusty" has a double meaning:\n\n1. A crust is a hard, outer layer on a pizza, typically made of bread.\n2. To be "crusty" can also mean to be in a bad mood or irritable.\n\nThe joke sets up the expectation that the pizza might be in a bad mood because of some external reason, but instead, it uses the word "crusty" to refer to the pizza\'s physical composition, creating a clever and unexpected connection between the setup and the punchline.\n\nThe humor comes from the unexpected twist on the word\'s meaning, which creates a surprise and a clever connection between the setup and the punchline.'}, next=(), config={'configurable': {'
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke relies on a play on words, which is a common technique used in puns. A pun is a form of wordplay that exploits multiple meanings of a word or phrase, often with a humorous effect.\n\nIn this case, the word "crusty" has a double meaning:\n\n1. A crust is a hard, outer layer on a pizza, typically made of bread.\n2. To be "crusty" can also mean to be in a bad mood or irritable.\n\nThe joke sets up the expectation that the pizza might be in a bad mood because of some external reason, but instead, it uses the word "crusty" to refer to the pizza\'s physical composition, creating a clever and unexpected connection between the setup and the punchline.\n\nThe humor comes from the unexpected twist on the word\'s meaning, which creates a surprise and a clever connection between the setup and the punchline.'}, next=(), config={'configurable': {
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted".',
#  'explanation': 'This joke plays on multiple layers of meaning, creating a pun that is the source of its humor. \n\nThe phrase "feeling a little twisted" has a double meaning here. In a psychological context, it implies that the spaghetti is experiencing emotional distress or turmoil. However, the word "twisted" also refers to the actual shape of spaghetti, which is long, thin, and often curved or bent into various forms while being cooked.\n\nThe joke relies on this dual meaning of "twisted" to create a clever connection between the setup (spaghetti going to therapy) and the punchline (it was feeling a little twisted). It uses wordplay to link the emotional state of the spaghetti with its physical characteristic, creating a humorous and unexpected twist (no pun intended) on the typical expectations of a joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke relies on a play on words, which is a common technique used in puns. A pun is a form of wordplay that exploits multiple meanings of a word or phrase, often with a humorous effect.\n\nIn this case, the word "crusty" has a double meaning:\n\n1. A crust is a hard, outer layer on a pizza, typically made of bread.\n2. To be "crusty" can also mean to be in a bad mood or irritable.\n\nThe joke sets up the expectation that the pizza might be in a bad mood because of some external reason, but instead, it uses the word "crusty" to refer to the pizza\'s physical composition, creating a clever and unexpected connection between the setup and the punchline.\n\nThe humor comes from the unexpected twist on the word\'s meaning, which creates a surprise and a clever connection between the setup and the punchline.'}, next=(), config={'configurable': {'
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke relies on a play on words, which is a common technique used in puns. A pun is a form of wordplay that exploits multiple meanings of a word or phrase, often with a humorous effect.\n\nIn this case, the word "crusty" has a double meaning:\n\n1. A crust is a hard, outer layer on a pizza, typically made of bread.\n2. To be "crusty" can also mean to be in a bad mood or irritable.\n\nThe joke sets up the expectation that the pizza might be in a bad mood because of some external reason, but instead, it uses the word "crusty" to refer to the pizza\'s physical composition, creating a clever and unexpected connection between the setup and the punchline.\n\nThe humor comes from the unexpected twist on the word\'s meaning, which creates a surprise and a clever connection between the setup and the punchline.'}, next=(), config={'configurable': {
# ...

# %% [markdown]
# ## Time travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f1040ee-98c3-6ea2-8000-446a6c5b6a19"}})
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f1040ee-98c3-6ea2-8000-446a6c5b6a19'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-02-07T10:22:31.953168+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1040ee-98c2-68f5-bfff-c5c551f0696d'}}, tasks=(PregelTask(id='b2d65747-6d6b-1440-7e8c-87d091b66744', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f1040ee-98c3-6ea2-8000-446a6c5b6a19"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little "crusty" and had a "saucy" attitude, but it turned out it just had a "gouda" day and was "melted" under the pressure.',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little "crusty" and had a "saucy" attitude, but it turned out it just had a "gouda" day and was "melted" under the pressure.', 'explanation': 'This is a play on words, using puns related to pizza toppings and characteristics to create a humorous explanation for why the pizza went to the doctor. Here\'s a breakdown of the joke:\n\n- "Feeling a little \'crusty\'" refers to the crust of the pizza, which is a common texture found on pizza. It\'s a clever way to begin the joke, setting the stage for the pizza-related puns.\n\n- "Had a \'saucy\' attitude" is a phrase used to describe someone with a bold or sassy personality. However, in the context of pizza, saucy would refer to the tomato sauce on the pizza, making it a clever play on words.\n\n- The punchline turns out that the pizza was just having a "good day" (gouda), which is a play on words referencing the cheese "Gouda
# ...

# %% [markdown]
# Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f1040ee-98c3-6ea2-8000-446a6c5b6a19", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1040f0-ec8f-6deb-8001-8c95c8b1e850'}}

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f1040ee-98c3-6ea2-8000-446a6c5b6a19"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'This joke relies on a play on words, combining a common phrase related to human emotions ("in a bad mood") with a characteristic of a pizza ("crusty"). The crust of a pizza is its outer layer, typically made from bread or dough. In human psychology, being "crusty" is also an idiomatic expression for someone being in a bad mood or having a rough exterior. \n\nThe humor comes from the unexpected twist on the typical phrase "in a bad mood," which is usually associated with humans. The joke replaces this phrase with a characteristic of a pizza, "crusty," to create a pun. This wordplay creates a sense of surprise and cleverness, making the joke amusing.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the samosa go to therapy? \n\nBecause it was feeling crumby and wanted to work through its wrapping issues.', 'explanation': 'This joke is a play on words, using puns to create a humorous effect. Here\'s a breakdown of how it works:\n\n- "Crumby" has a double meaning. In everyday language, "crumby" can mean something is of poor quality or in a state of disrepair. However, the term "crumby" is also associated with crumpets, a type of British baked good, and crumbly pastry. Given that samosas are fried or baked pastry pockets, the word "crumby" is used here to make a connection to the pastry.\n\n- "Wrapping issues" is a phrase commonly used in therapy or counseling to refer to emotional or psychological problems related to interpersonal relationships or personal boundaries. However, in the context of a samosa, "wrapping" refers to the pastry dough used to enclose the filling. This pun creates a connection between the pastry and
# ...

# %% [markdown]
# ## Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
list(graph.get_state_history(config1))
# Out:
# []

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))

# %%
#
